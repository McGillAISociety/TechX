# %% [markdown]
# # Data Manipulation Demo

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Read the csv file 'assault.csv'**

# %%
assault_df = pd.read_csv('./dataset/assault.csv')

# %% [markdown]
# **Display the Dataframe to study it**

# %%
assault_df
# Out:
#       Area_unit_2013_code             Area_unit_2013_label  \
# 0                  514102            Auckland Central West
# 1                  573101  Willis Street-Cambridge Terrace
# 2                  529700                 Hamilton Central
# 3                  514103            Auckland Central East
# 4                  591500                 Cathedral Square
# 5                  514101             Auckland Harbourside
# 6                  524604                  Manukau Central
# 7                  562800         Palmerston North Central
# 8                  540410                           Kuirau
# 9                  538201                 Tauranga Central
# 10                 603100           Stuart St-Frederick St
# 11                 521901                     Otahuhu West
# 12                 582500                        Trafalgar
# 13                 548200                 Hastings Central
# 14                 544600                 Gisborne Central
# 15                 587821                          Paparua
# 16                 609302                  Queenstown Hill
# 17                 522202               Papatoetoe Central
# 18                 603000                High St-Stuart St
# 19                 569100                     Hutt Central
# 20                 573000                          Lambton
# 21                 524602                             Wiri
# 22                 551800             New Plymouth Central
# 23                 514200                           Newton
# 24                 570800                  Porirua Central
# 25                 511303                         Lynnmall
# 26                 581230                 Blenheim Central
# 27                 525910                   Pukekohe North
# 28                 609304                   Queenstown Bay
# 29                 541720                    Taupo Central
# ...                   ...                              ...
# 1990               567902                         Mangaroa
# 1991               602412                         Wingatui
# 1992               586801                     Ashley Gorge
# 1993               555300                         Blueskin
# 1994               513420                           Herald
# 1995               505605                       Kumeu West
# 1996               603710                       Maori Hill
# 1997               587844                      Westmorland
# 1998               522603                       Bleakhouse
# 1999               586122                          Lehmans
# 2000               551024                          Barrett
# 2001               523201                      Shelly Park
# 2002               597507             Rolleston North West
# 2003               597510             Rolleston South West
# 2004               585807                           Loburn
# 2005               509500                      Stanley Bay
# 2006               551111                        Lepperton
# 2007               512700                            Waima
# 2008               512801                        Laingholm
# 2009               507500                    Campbells Bay
# 2010               574200     Khandallah Park-Broadmeadows
# 2011               610040                          Hokonui
# 2012               586603                       Mandeville
# 2013               574401                           Awarua
# 2014               573514               Churton Park South
# 2015               506653                        Riverhead
# 2016               610601                         Grasmere
# 2017               536513                   Bethlehem East
# 2018               574302                        Te Kainga
# 2019               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# 1                                   447                       8300
# 2                                   380                       3170
# 3                                   375                      13250
# 4                                   305                        570
# 5                                   253                       5680
# 6                                   192                        900
# 7                                   190                       3060
# 8                                   168                       1290
# 9                                   167                       2270
# 10                                  154                       3360
# 11                                  148                       5400
# 12                                  138                        550
# 13                                  130                       2970
# 14                                  128                       3380
# 15                                  121                        890
# 16                                  113                       4100
# 17                                  109                       5120
# 18                                  107                       2540
# 19                                  105                       4070
# 20                                  104                       6000
# 21                                  103                       4390
# 22                                  102                        680
# 23                                  101                       2170
# 24                                   96                        410
# 25                                   94                       2610
# 26                                   91                       2790
# 27                                   91                       9980
# 28                                   90                       2360
# 29                                   90                       3900
# ...                                 ...                        ...
# 1990                                  0                       1750
# 1991                                  0                       1780
# 1992                                  0                       1830
# 1993                                  0                       1840
# 1994                                  0                       1860
# 1995                                  0                       1880
# 1996                                  0                       1970
# 1997                                  0                       1990
# 1998                                  0                       2070
# 1999                                  0                       2200
# 2000                                  0                       2240
# 2001                                  0                       2310
# 2002                                  0                       2330
# 2003                                  0                       2330
# 2004                                  0                       2390
# 2005                                  0                       2440
# 2006                                  0                       2510
# 2007                                  0                       2600
# 2008                                  0                       2620
# 2009                                  0                       2630
# 2010                                  0                       2960
# 2011                                  0                       3090
# 2012                                  0                       3160
# 2013                                  0                       3310
# 2014                                  0                       3440
# 2015                                  0                       3510
# 2016                                  0                       3590
# 2017                                  0                       3590
# 2018                                  0                       4020
# 2019                                  0                       5440
#
#       Urban_area_2013_code                Urban_area_2013_label  \
# 0                        4                Central Auckland Zone
# 1                       20                      Wellington Zone
# 2                        6                        Hamilton Zone
# 3                        4                Central Auckland Zone
# 4                       22                         Christchurch
# 5                        4                Central Auckland Zone
# 6                        5               Southern Auckland Zone
# 7                       16                     Palmerston North
# 8                       10                              Rotorua
# 9                        9                             Tauranga
# 10                      23                              Dunedin
# 11                       4                Central Auckland Zone
# 12                      21                               Nelson
# 13                      13                        Hastings Zone
# 14                      11                             Gisborne
# 15                      22                         Christchurch
# 16                     117                           Queenstown
# 17                       5               Southern Auckland Zone
# 18                      23                              Dunedin
# 19                      18                      Lower Hutt Zone
# 20                      20                      Wellington Zone
# 21                       5               Southern Auckland Zone
# 22                      14                         New Plymouth
# 23                       4                Central Auckland Zone
# 24                      19                         Porirua Zone
# 25                       3                Western Auckland Zone
# 26                      26                             Blenheim
# 27                     101                             Pukekohe
# 28                     117                           Queenstown
# 29                     103                                Taupo
# ...                    ...                                  ...
# 1990                   502  Rural (Incl.some Off Shore Islands)
# 1991                    23                              Dunedin
# 1992                   502  Rural (Incl.some Off Shore Islands)
# 1993                    15                             Wanganui
# 1994                     3                Western Auckland Zone
# 1995                     3                Western Auckland Zone
# 1996                    23                              Dunedin
# 1997                    22                         Christchurch
# 1998                     5               Southern Auckland Zone
# 1999                   116                             Rangiora
# 2000                    14                         New Plymouth
# 2001                     5               Southern Auckland Zone
# 2002                   300                            Rolleston
# 2003                   300                            Rolleston
# 2004                   502  Rural (Incl.some Off Shore Islands)
# 2005                     2               Northern Auckland Zone
# 2006                   502  Rural (Incl.some Off Shore Islands)
# 2007                     3                Western Auckland Zone
# 2008                     3                Western Auckland Zone
# 2009                     2               Northern Auckland Zone
# 2010                    20                      Wellington Zone
# 2011                   502  Rural (Incl.some Off Shore Islands)
# 2012                   502  Rural (Incl.some Off Shore Islands)
# 2013                    20                      Wellington Zone
# 2014                    20                      Wellington Zone
# 2015                   502  Rural (Incl.some Off Shore Islands)
# 2016                    24                         Invercargill
# 2017                     9                             Tauranga
# 2018                    20                      Wellington Zone
# 2019                     6                        Hamilton Zone
#
#            Urban_area_type
# 0          Main urban area
# 1          Main urban area
# 2          Main urban area
# 3          Main urban area
# 4          Main urban area
# 5          Main urban area
# 6          Main urban area
# 7          Main urban area
# 8          Main urban area
# 9          Main urban area
# 10         Main urban area
# 11         Main urban area
# 12         Main urban area
# 13         Main urban area
# 14         Main urban area
# 15         Main urban area
# 16    Secondary urban area
# 17         Main urban area
# 18         Main urban area
# 19         Main urban area
# 20         Main urban area
# 21         Main urban area
# 22         Main urban area
# 23         Main urban area
# 24         Main urban area
# 25         Main urban area
# 26         Main urban area
# 27    Secondary urban area
# 28    Secondary urban area
# 29    Secondary urban area
# ...                    ...
# 1990            Rural area
# 1991       Main urban area
# 1992            Rural area
# 1993       Main urban area
# 1994       Main urban area
# 1995       Main urban area
# 1996       Main urban area
# 1997       Main urban area
# 1998       Main urban area
# 1999  Secondary urban area
# 2000       Main urban area
# 2001       Main urban area
# 2002      Minor urban area
# 2003      Minor urban area
# 2004            Rural area
# 2005       Main urban area
# 2006            Rural area
# 2007       Main urban area
# 2008       Main urban area
# 2009       Main urban area
# 2010       Main urban area
# 2011            Rural area
# 2012            Rural area
# 2013       Main urban area
# 2014       Main urban area
# 2015            Rural area
# 2016       Main urban area
# 2017       Main urban area
# 2018       Main urban area
# 2019       Main urban area
#
# [2020 rows x 7 columns]

# %% [markdown]
# **Only display the first 20 lines of the dataframe**

# %%
assault_df.head(20)
# Out:
#     Area_unit_2013_code             Area_unit_2013_label  \
# 0                514102            Auckland Central West
# 1                573101  Willis Street-Cambridge Terrace
# 2                529700                 Hamilton Central
# 3                514103            Auckland Central East
# 4                591500                 Cathedral Square
# 5                514101             Auckland Harbourside
# 6                524604                  Manukau Central
# 7                562800         Palmerston North Central
# 8                540410                           Kuirau
# 9                538201                 Tauranga Central
# 10               603100           Stuart St-Frederick St
# 11               521901                     Otahuhu West
# 12               582500                        Trafalgar
# 13               548200                 Hastings Central
# 14               544600                 Gisborne Central
# 15               587821                          Paparua
# 16               609302                  Queenstown Hill
# 17               522202               Papatoetoe Central
# 18               603000                High St-Stuart St
# 19               569100                     Hutt Central
#
#     Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                 550                      15900
# 1                                 447                       8300
# 2                                 380                       3170
# 3                                 375                      13250
# 4                                 305                        570
# 5                                 253                       5680
# 6                                 192                        900
# 7                                 190                       3060
# 8                                 168                       1290
# 9                                 167                       2270
# 10                                154                       3360
# 11                                148                       5400
# 12                                138                        550
# 13                                130                       2970
# 14                                128                       3380
# 15                                121                        890
# 16                                113                       4100
# 17                                109                       5120
# 18                                107                       2540
# 19                                105                       4070
#
#     Urban_area_2013_code   Urban_area_2013_label       Urban_area_type
# 0                      4   Central Auckland Zone       Main urban area
# 1                     20         Wellington Zone       Main urban area
# 2                      6           Hamilton Zone       Main urban area
# 3                      4   Central Auckland Zone       Main urban area
# 4                     22            Christchurch       Main urban area
# 5                      4   Central Auckland Zone       Main urban area
# 6                      5  Southern Auckland Zone       Main urban area
# 7                     16        Palmerston North       Main urban area
# 8                     10                 Rotorua       Main urban area
# 9                      9                Tauranga       Main urban area
# 10                    23                 Dunedin       Main urban area
# 11                     4   Central Auckland Zone       Main urban area
# 12                    21                  Nelson       Main urban area
# 13                    13           Hastings Zone       Main urban area
# 14                    11                Gisborne       Main urban area
# 15                    22            Christchurch       Main urban area
# 16                   117              Queenstown  Secondary urban area
# 17                     5  Southern Auckland Zone       Main urban area
# 18                    23                 Dunedin       Main urban area
# 19                    18         Lower Hutt Zone       Main urban area

# %% [markdown]
# **What about Display the last 10 rows?**

# %%
assault_df.tail(10)
# Out:
#       Area_unit_2013_code          Area_unit_2013_label  \
# 2010               574200  Khandallah Park-Broadmeadows
# 2011               610040                       Hokonui
# 2012               586603                    Mandeville
# 2013               574401                        Awarua
# 2014               573514            Churton Park South
# 2015               506653                     Riverhead
# 2016               610601                      Grasmere
# 2017               536513                Bethlehem East
# 2018               574302                     Te Kainga
# 2019               527007                 Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 2010                                  0                       2960
# 2011                                  0                       3090
# 2012                                  0                       3160
# 2013                                  0                       3310
# 2014                                  0                       3440
# 2015                                  0                       3510
# 2016                                  0                       3590
# 2017                                  0                       3590
# 2018                                  0                       4020
# 2019                                  0                       5440
#
#       Urban_area_2013_code                Urban_area_2013_label  \
# 2010                    20                      Wellington Zone
# 2011                   502  Rural (Incl.some Off Shore Islands)
# 2012                   502  Rural (Incl.some Off Shore Islands)
# 2013                    20                      Wellington Zone
# 2014                    20                      Wellington Zone
# 2015                   502  Rural (Incl.some Off Shore Islands)
# 2016                    24                         Invercargill
# 2017                     9                             Tauranga
# 2018                    20                      Wellington Zone
# 2019                     6                        Hamilton Zone
#
#       Urban_area_type
# 2010  Main urban area
# 2011       Rural area
# 2012       Rural area
# 2013  Main urban area
# 2014  Main urban area
# 2015       Rural area
# 2016  Main urban area
# 2017  Main urban area
# 2018  Main urban area
# 2019  Main urban area

# %% [markdown]
# **Get the list of all the column names**

# %%
assault_df.columns
# Out:
# Index(['Area_unit_2013_code', 'Area_unit_2013_label',
#        'Victimisations_calendar_year_2015', 'Population_mid_point_2015',
#        'Urban_area_2013_code', 'Urban_area_2013_label', 'Urban_area_type'],
#       dtype='object')

# %% [markdown]
# **The column names are really long, let's replace them with shorter names**

# %%
assault_df.rename(columns={'Victimisations_calendar_year_2015': 'Victimisations', 
                            'Population_mid_point_2015': 'Population'}, inplace=True)

# %%
assault_df.head()
# Out:
#    Area_unit_2013_code             Area_unit_2013_label  Victimisations  \
# 0               514102            Auckland Central West             550
# 1               573101  Willis Street-Cambridge Terrace             447
# 2               529700                 Hamilton Central             380
# 3               514103            Auckland Central East             375
# 4               591500                 Cathedral Square             305
#
#    Population  Urban_area_2013_code  Urban_area_2013_label  Urban_area_type
# 0       15900                     4  Central Auckland Zone  Main urban area
# 1        8300                    20        Wellington Zone  Main urban area
# 2        3170                     6          Hamilton Zone  Main urban area
# 3       13250                     4  Central Auckland Zone  Main urban area
# 4         570                    22           Christchurch  Main urban area

# %% [markdown]
# **Create a column with the rate of victimisations**

# %% [markdown]
# But first, let's remove all the rows with 0 population.... WILL HAVE A PROBLEM!

# %%
assault_df = assault_df[assault_df['Population'] != 0]

# %%
assault_df['Rate'] = assault_df['Victimisations'] / assault_df['Population'] * 100
# Out:
# /Users/TiffanyWang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
assault_df.head()
# Out:
#    Area_unit_2013_code             Area_unit_2013_label  Victimisations  \
# 0               514102            Auckland Central West             550
# 1               573101  Willis Street-Cambridge Terrace             447
# 2               529700                 Hamilton Central             380
# 3               514103            Auckland Central East             375
# 4               591500                 Cathedral Square             305
#
#    Population  Urban_area_2013_code  Urban_area_2013_label  Urban_area_type  \
# 0       15900                     4  Central Auckland Zone  Main urban area
# 1        8300                    20        Wellington Zone  Main urban area
# 2        3170                     6          Hamilton Zone  Main urban area
# 3       13250                     4  Central Auckland Zone  Main urban area
# 4         570                    22           Christchurch  Main urban area
#
#         Rate
# 0   3.459119
# 1   5.385542
# 2  11.987382
# 3   2.830189
# 4  53.508772

# %% [markdown]
# **Sort the rows in ascending victimisation rate order**

# %%
assault_df.sort_values(by='Rate', inplace=True)
# Out:
# /Users/TiffanyWang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
assault_df.head()
# Out:
#       Area_unit_2013_code Area_unit_2013_label  Victimisations  Population  \
# 2019               527007        Horsham Downs               0        5440
# 1819               541347             Motuoapa               0         250
# 1820               521115           Opuawhanga               0         250
# 1821               526106            Pukeoware               0         250
# 1822               609014       Kingston South               0         260
#
#       Urban_area_2013_code                Urban_area_2013_label  \
# 2019                     6                        Hamilton Zone
# 1819                   502  Rural (Incl.some Off Shore Islands)
# 1820                   101                             Pukekohe
# 1821                   215                               Waiuku
# 1822                   502  Rural (Incl.some Off Shore Islands)
#
#            Urban_area_type  Rate
# 2019       Main urban area   0.0
# 1819            Rural area   0.0
# 1820  Secondary urban area   0.0
# 1821      Minor urban area   0.0
# 1822            Rural area   0.0

# %%
assault_df.tail()
# Out:
#      Area_unit_2013_code Area_unit_2013_label  Victimisations  Population  \
# 691               602800          Harbourside               8          30
# 31                503100    Whangarei Central              87         280
# 69                521902           Middlemore              53         110
# 4                 591500     Cathedral Square             305         570
# 261               523112            Highbrook              23          40
#
#      Urban_area_2013_code   Urban_area_2013_label  Urban_area_type       Rate
# 691                    23                 Dunedin  Main urban area  26.666667
# 31                      1               Whangarei  Main urban area  31.071429
# 69                      5  Southern Auckland Zone  Main urban area  48.181818
# 4                      22            Christchurch  Main urban area  53.508772
# 261                     5  Southern Auckland Zone  Main urban area  57.500000

# %% [markdown]
# **Remove the columns with NaN (does not exist) rate.**

# %%
assault_df.dropna(subset=['Rate'], inplace=True)
# Out:
# /Users/TiffanyWang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
assault_df.tail()
# Out:
#      Area_unit_2013_code Area_unit_2013_label  Victimisations  Population  \
# 691               602800          Harbourside               8          30
# 31                503100    Whangarei Central              87         280
# 69                521902           Middlemore              53         110
# 4                 591500     Cathedral Square             305         570
# 261               523112            Highbrook              23          40
#
#      Urban_area_2013_code   Urban_area_2013_label  Urban_area_type       Rate
# 691                    23                 Dunedin  Main urban area  26.666667
# 31                      1               Whangarei  Main urban area  31.071429
# 69                      5  Southern Auckland Zone  Main urban area  48.181818
# 4                      22            Christchurch  Main urban area  53.508772
# 261                     5  Southern Auckland Zone  Main urban area  57.500000

# %% [markdown]
# **Create a safe / dangerous label based on the Victimisation rate**

# %%
assault_df['Safe_Label'] = assault_df['Rate'] < 20
# Out:
# /Users/TiffanyWang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
assault_df.head()
# Out:
#       Area_unit_2013_code Area_unit_2013_label  Victimisations  Population  \
# 2019               527007        Horsham Downs               0        5440
# 1819               541347             Motuoapa               0         250
# 1820               521115           Opuawhanga               0         250
# 1821               526106            Pukeoware               0         250
# 1822               609014       Kingston South               0         260
#
#       Urban_area_2013_code                Urban_area_2013_label  \
# 2019                     6                        Hamilton Zone
# 1819                   502  Rural (Incl.some Off Shore Islands)
# 1820                   101                             Pukekohe
# 1821                   215                               Waiuku
# 1822                   502  Rural (Incl.some Off Shore Islands)
#
#            Urban_area_type  Rate  Safe_Label
# 2019       Main urban area   0.0        True
# 1819            Rural area   0.0        True
# 1820  Secondary urban area   0.0        True
# 1821      Minor urban area   0.0        True
# 1822            Rural area   0.0        True

# %%
assault_df.tail()
# Out:
#      Area_unit_2013_code Area_unit_2013_label  Victimisations  Population  \
# 691               602800          Harbourside               8          30
# 31                503100    Whangarei Central              87         280
# 69                521902           Middlemore              53         110
# 4                 591500     Cathedral Square             305         570
# 261               523112            Highbrook              23          40
#
#      Urban_area_2013_code   Urban_area_2013_label  Urban_area_type       Rate  \
# 691                    23                 Dunedin  Main urban area  26.666667
# 31                      1               Whangarei  Main urban area  31.071429
# 69                      5  Southern Auckland Zone  Main urban area  48.181818
# 4                      22            Christchurch  Main urban area  53.508772
# 261                     5  Southern Auckland Zone  Main urban area  57.500000
#
#      Safe_Label
# 691       False
# 31        False
# 69        False
# 4         False
# 261       False

# %% [markdown]
# **List all the rows that are considered 'safe'**

# %%
safe_df = assault_df[assault_df['Safe_Label'] == True]

# %%
assault_df.tail()
# Out:
#      Area_unit_2013_code Area_unit_2013_label  Victimisations  Population  \
# 691               602800          Harbourside               8          30
# 31                503100    Whangarei Central              87         280
# 69                521902           Middlemore              53         110
# 4                 591500     Cathedral Square             305         570
# 261               523112            Highbrook              23          40
#
#      Urban_area_2013_code   Urban_area_2013_label  Urban_area_type       Rate  \
# 691                    23                 Dunedin  Main urban area  26.666667
# 31                      1               Whangarei  Main urban area  31.071429
# 69                      5  Southern Auckland Zone  Main urban area  48.181818
# 4                      22            Christchurch  Main urban area  53.508772
# 261                     5  Southern Auckland Zone  Main urban area  57.500000
#
#      Safe_Label
# 691       False
# 31        False
# 69        False
# 4         False
# 261       False

# %%
safe_df.tail()
# Out:
#      Area_unit_2013_code  Area_unit_2013_label  Victimisations  Population  \
# 974               538202         Sulphur Point               4          30
# 15                587821               Paparua             121         890
# 747               503900      Port-Limeburners               7          50
# 22                551800  New Plymouth Central             102         680
# 67                567100    Upper Hutt Central              54         330
#
#      Urban_area_2013_code Urban_area_2013_label  Urban_area_type       Rate  \
# 974                     9              Tauranga  Main urban area  13.333333
# 15                     22          Christchurch  Main urban area  13.595506
# 747                     1             Whangarei  Main urban area  14.000000
# 22                     14          New Plymouth  Main urban area  15.000000
# 67                     17       Upper Hutt Zone  Main urban area  16.363636
#
#      Safe_Label
# 974        True
# 15         True
# 747        True
# 22         True
# 67         True

# %% [markdown]
# **Save the dataframe in a .csv file for future use!**

# %%
safe_df.to_csv('assault_changed.csv')
